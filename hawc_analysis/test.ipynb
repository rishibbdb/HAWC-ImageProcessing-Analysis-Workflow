# %%
from core.config import ConfigManager
from core.logger import PipelineLogger
from core.checkpoint import CheckpointManager
from core.directory_manager import DirectoryManager
from core.data_loading import DataLoader
from core.plotting import PlottingUtilities
from core.map_tools import MapGenerator
from core.roi_tools import ROITools
from core.model_generator import ModelGenerator
from core.hdf5_handler import HDF5Handler
# Out:
# 18:15:49 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=7274608;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=7274609;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#43\43]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=7274615;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=7274616;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/functions/functions_1D/functions.py#65\65]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=7274623;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=7274624;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
# 18:15:49 INFO      Starting 3ML!                                                                     ]8;id=7274631;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274632;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#44\44]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=7274638;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274639;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#45\45]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=7274645;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274646;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#46\46]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=7274652;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274653;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#47\47]8;;\
#          WARNING   no display variable set. using backend for graphics without display (agg)         ]8;id=7274659;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274660;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#53\53]8;;\
# In file included from input_line_47:1:
# In file included from /Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/include/CPyCppyy/API.h:26:
# In file included from /Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/include/python3.12/Python.h:92:
# /Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/include/python3.12/compile.h:8:9: warning: 'Py_single_input' macro redefined [-Wmacro-redefined]
# #define Py_single_input 256
#         ^
# :49:56: note: previous definition is here
# template <class T> [[nodiscard]] constexpr T* launder(T* p) noexcept;   // C++17, nodiscard since C++20
#                                                        ^
#          WARNING   Multinest minimizer not available                                           ]8;id=7274667;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=7274668;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1218\1218]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=7274674;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=7274675;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/minimizer/minimization.py#1228\1228]8;;\
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=7274681;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274682;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#126\126]8;;\
#                   software installed and configured?
# 18:15:50 WARNING   No fermitools installed                                              ]8;id=7274689;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=7274690;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=7274696;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274697;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=7274702;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274703;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=7274708;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=7274709;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/threeML/__init__.py#335\335]8;;\
#                   performances in 3ML

# %%
config = ConfigManager('config.yaml')
method = config.get('fitting_procedure')
ra = config.get('coordinates.ra', 0.0)
output_path = config.get('output_dir', './')
output_dir_name = config.get('fit_name', 'fit_results')

# %%
# Test logger
logger = PipelineLogger('./logs')
logger.info("Pipeline test")

# Test checkpoint
checkpoint = CheckpointManager('./checkpoints')
print("✓ All systems ready!")
# Out:
# 2026-07-18 18:15:51 - Pipeline - INFO - Pipeline logger initialized
# 2026-07-18 18:15:51 - Pipeline - INFO - Log level: INFO
# 2026-07-18 18:15:51 - Pipeline - INFO - Pipeline log: logs/pipeline_20260718_181551.log
# 2026-07-18 18:15:51 - Pipeline - INFO - Full log: logs/full_log_20260718_181551.log
# 2026-07-18 18:15:51 - Pipeline - INFO - Pipeline test
# ✓ All systems ready!

# %%
dm = DirectoryManager(output_path, output_dir_name, logger=logger)
dm.create_structure()

# Get paths
model_path = dm.get_model_file_path('Step0-Allpoint-sources')
results_dir = dm.get_step_results_dir('Step0-Allpoint-sources')
sig_map = dm.get_significance_map_path()

# List steps
steps = dm.list_steps()

# Main directories
datamap_dir = dm.get_datamap_dir()      # fit_name/DataMap/
logs_dir = dm.get_logs_dir()            # fit_name/Logs/
models_dir = dm.get_models_dir()        # fit_name/Models/
fit_results_dir = dm.get_fit_results_dir()  # fit_name/FitResults/

# Step-specific directories
step_dir = dm.get_step_results_dir('Step0-Allpoint-sources')
# Returns: fit_name/FitResults/Step0-Allpoint-sources/

model_path = dm.get_model_file_path('Step0-Allpoint-sources')
# Returns: fit_name/Models/Step0-Allpoint-sources.model

# Fit results YAML
results_path = dm.get_fit_results_file_path('Step0-Allpoint-sources')
# Returns: fit_name/FitResults/Step0-Allpoint-sources/fit_results.yaml

# HDF5 maps
model_hdf5 = dm.get_hdf5_file_path('Step0-Allpoint-sources', 'model')
residual_hdf5 = dm.get_hdf5_file_path('Step0-Allpoint-sources', 'residual')
# Returns: fit_name/FitResults/Step0-Allpoint-sources/model_fit.hd5
#          fit_name/FitResults/Step0-Allpoint-sources/residual_fit.hd5

# Significance map
sig_map = dm.get_significance_map_path()
# Out:
# 2026-07-18 18:15:51 - Pipeline - INFO - Initialized DirectoryManager at fit_results
# 2026-07-18 18:15:51 - Pipeline - INFO - Directory structure created at fit_results

# %%
step_name = 'Step1-Testsource1extension'
step_dir = dm.get_step_results_dir(step_name)

# %%
# %load_ext autoreload
# %autoreload 2

config = ConfigManager('config.yaml')

sigmap = config.get('coordinates.sig_map_path')
ra = config.get('coordinates.ra')
dec = config.get('coordinates.dec')
roi_x = config.get('coordinates.roi_x')
roi_y = config.get('coordinates.roi_y')
coord_sys = config.get('coordinates.coord_sys')
print(f"Loading HAWC data from {sigmap} with center RA={ra}, Dec={dec}, ROI size=({roi_x}, {roi_y}), coordinate system={coord_sys}")
array, footprint, wcs, xnum, ynum, pixel_size = DataLoader.load_hawc_data(
    filename=sigmap,
    center_x=ra,
    center_y=dec,
    x_length=roi_x,
    y_length=roi_y,
    coord_sys=coord_sys,
    logger=logger
)
# Out:
# 2026-07-18 18:15:51 - Pipeline - INFO - Loading HAWC data: Celestial RA=83.5, Dec=22.0
# Loading HAWC data from /Users/rishi/Documents/Analysis/data/aligned-ml-wholesky-neg-ext0.0.fits.gz with center RA=83.5, Dec=22.0, ROI size=(4.0, 4.0), coordinate system=C
# Loading Celestial Map
# 2026-07-18 18:15:54 - Pipeline - INFO - Loaded map dimensions: 1440x1440 pixels
# 2026-07-18 18:15:54 - Pipeline - INFO - Pixel size: 0.005556 degrees/pixel
# Fits File loaded

# %%
# Find peak significance
peak_value, peak_index, sky_coord, significance = DataLoader.find_peak(
    array, wcs, logger=logger
)

# Extract ROI
roi_array, roi_wcs = DataLoader.extract_roi(
    array, wcs, roi_x_deg=2.0, roi_y_deg=2.0
)
# Out:
# 2026-07-18 04:01:39 - Pipeline - INFO - Peak pixel location: (np.int64(724), np.int64(700))
# 2026-07-18 04:01:39 - Pipeline - INFO - Peak sky location: <SkyCoord (ICRS): (ra, dec) in deg
#     (83.62647266, 22.02496031)>
# 2026-07-18 04:01:39 - Pipeline - INFO - Peak significance: 355.86 sigma

# %%
fig, ax = PlottingUtilities.make_plots(
    array=array,
    wcs=wcs,
    coord_sys='C',
    threshold=4,
    vmin=-5,
    vmax=15,
    title='Significance Map',
    contour=True,
    save_path='sig_map.png',
    cmap='ult'
)

# Create log-scale plot
fig, ax = PlottingUtilities.make_logplots(
    array=array,
    wcs=wcs,
    coord_sys='C',
    title='Log Significance Map',
    save_path='sig_map_log.png'
)

# %%
config = ConfigManager('config.yaml')
countmap_dir = config.get('coordinates.count_map_dir')
image_bins = config.get('coordinates.image_bins')
detector_response = config.get('coordinates.detector_response', 'detRes.root')
print(f"Finding FITS files in {countmap_dir} for energy bins: {image_bins}")
fits_mapping = MapGenerator.find_fits_files_by_bins(
    data_directory=countmap_dir,
    energy_bins=image_bins,
    logger=logger
)

# # Create HEALPix map
# import os
# os.chdir('/Users/rishi/Documents/Analysis/aerie')

output_map = MapGenerator.create_healpix_map(
    input_fits_files=list(fits_mapping.values()),
    energy_bins=list(fits_mapping.keys()),
    detector_response=detector_response,
    ra_center=83.5,
    dec_center=22.0,
    roi_x=4.0,
    roi_y=4.0,
    output_file='significance_map.fits',
    spectral_index=2.6,
    logger=logger
)
# Out:
# 2026-07-18 18:16:15 - Pipeline - INFO - Searching for FITS files in /Users/rishi/Documents/Analysis/data/fhitcountmaps/
# 2026-07-18 18:16:15 - Pipeline - INFO - Looking for bins: ['B2C0']
# 2026-07-18 18:16:15 - Pipeline - INFO - Found 1/1 energy bins
# 2026-07-18 18:16:15 - Pipeline - INFO - Creating HEALPix map from 1 FITS files
# 2026-07-18 18:16:15 - Pipeline - INFO - Energy bins: ['B2C0']
# 2026-07-18 18:16:15 - Pipeline - INFO - Executing HealpixSigFluxMap command:
# 2026-07-18 18:16:15 - Pipeline - ERROR - HealpixSigFluxMap command failed: Command '['pixi', 'run', 'aerie-apps-HealpixSigFluxMap', '-i', '/Users/rishi/Documents/Analysis/data/fhitcountmaps/binB2C0-rejiggered.fits.gz', '-b', 'B2C0', '-d', '/Users/rishi/Documents/Analysis/data/detRes-fhit2pct-pass5f-mlp-refit.root', '--index', '2.6', '--pivot', '7', '--window', '83.5', '22.0', '5.0', '5.0', '--negFlux', '--negSignif', '-o', 'significance_map.fits']' returned non-zero exit status 1.
# 2026-07-18 18:16:15 - Pipeline - ERROR - STDOUT:
# 2026-07-18 18:16:15 - Pipeline - ERROR - STDERR: Error:   × could not find pixi.toml or pyproject.toml with tool.pixi at directory /
#   │ Users/rishi/Documents/Analysis/Sources/AstroImageDetection-fitmodel/HAWC-
#   │ ImageProcessing-3MLFit/hawc_analysis
# Finding FITS files in /Users/rishi/Documents/Analysis/data/fhitcountmaps/ for energy bins: ['B2C0']

# %%
# from core.config import ConfigManager
# from core.logger import PipelineLogger
# from core.directory_manager import DirectoryManager
# from seeding.image_seeds import DRIPSSeeder
# from seeding.alps_seeds import ALPSSeeder

# config = ConfigManager('config.yaml')
# logger = PipelineLogger(config.get('metadata.output_dir'))
# dm = DirectoryManager(config.get('metadata.output_dir'), config.get('metadata.fit_name'))

# # Choose seeding method
# method = config.get('phase0.method')  # 'image_seeds' or 'alps_seeds'

# if method == 'image_seeds':
#     seeder = DRIPSSeeder(config, logger, dm)
# else:
#     seeder = ALPSSeeder(config, logger, dm)

# output = seeder.run()
# print(output.summary())

# %%
from seeding.image_seeds import DRIPSSeeder

seeder = DRIPSSeeder(config, logger, dm)
output = seeder.run()          # SeedingOutput
print(output.source_info_db)   # filtered_df
# Out:
# 2026-07-18 04:07:33 - Pipeline - INFO - Initialized DRIPSSeeder
# 2026-07-18 04:07:33 - Pipeline - INFO - ============================================================
# 2026-07-18 04:07:33 - Pipeline - INFO - STARTING DRIPS SEEDING
# 2026-07-18 04:07:33 - Pipeline - INFO - ============================================================
# ROI center in Galactic Coordintes = 184.50331899583432, -5.89631109590247
# Loading Galactic Map
# Fits File loaded
# Degrees per pixel: 0.005555555555555556
#   Map shape  : 1440 × 1440  |  pixel size: 0.0056°
#   Sig range  : [-4.54, 355.82]
# Peak intensity pixel location: (np.int64(739), np.int64(711))
# Peak intensity sky location: <SkyCoord (Galactic): (l, b) in deg
#     (184.54799094, -5.78519819)>
# Peak intensity value: 355.8174185764037
# Plotting contours [7, 9, 12, 13, 14, 15]
#   Max significance 355.82sigma exceeds threshold 5.0sigma — proceeding with analysis.
# Processing radius 0.25°:   0%|          | 0/4 [00:00<?, ?it/s]
# Number of pixels corresponding to 0.25 smear radius = 45.00
# Estimated background RMS: 0.0020779275476142047
# Processing radius 0.30°:  25%|██▌       | 1/4 [00:05<00:17,  5.81s/it]
# Raw blobs — point source: 3, extended: 1
# Sources after 5$\sigma$ filtering: 3
# Number of pixels corresponding to 0.30 smear radius = 54.00
# Estimated background RMS: 0.002255636876633648
# Processing radius 0.40°:  50%|█████     | 2/4 [00:11<00:11,  5.88s/it]
# Raw blobs — point source: 3, extended: 1
# Sources after 5$\sigma$ filtering: 3
# Number of pixels corresponding to 0.40 smear radius = 72.00
# Estimated background RMS: 0.0025245135780272215
# Processing radius 0.50°:  75%|███████▌  | 3/4 [00:17<00:06,  6.01s/it]
# Raw blobs — point source: 3, extended: 1
# Sources after 5$\sigma$ filtering: 3
# Number of pixels corresponding to 0.50 smear radius = 90.00
# Estimated background RMS: 0.0027978972764661336
# Raw blobs — point source: 3, extended: 1
# Sources after 5$\sigma$ filtering: 3
#   PS  after all cuts:    2
#   EXT after all cuts:    1
# Plotting contours [7, 9, 12, 13, 14, 15]
# Intensity Fraction of pixels greater than 5 sigma detection threshold = 100.0%
# Larger blob coord = (np.float64(184.55357543343712), np.float64(-5.790753275246138))
#   No smaller blobs overlapping larger blob — tagging as EXT
#   Very close PS blob at (x=709, y=739, r=27.00 pixels) with sep=0.008° — tagging as EXT
# PS flagged: 1
#   Kept   — PS: 2  EXT: 0
#   Removed— PS: 0  EXT: 1
#   PS dedup: 2 → 2 kept, 0 removed
# Final — PS kept: 2  EXT kept: 0
#         PS removed: 0  EXT removed: 1
#   Kept   — PS: 2  EXT: 0
#   Removed— PS: 0  EXT: 1
# 2026-07-18 04:08:02 - Pipeline - INFO - Found 2 sources, 2 within original ROI
# 2026-07-18 04:08:02 - Pipeline - INFO - Results saved to: /Users/rishi/Documents/Analysis/Sources/AstroImageDetection-fitmodel/HAWC-ImageProcessing-3MLFit//SourceDetection/filtered_sources.yaml
# 2026-07-18 04:08:02 - Pipeline - INFO - Results saved to: /Users/rishi/Documents/Analysis/Sources/AstroImageDetection-fitmodel/HAWC-ImageProcessing-3MLFit//SourceDetection/filtered_sources.yaml
# Converting blob at (x=709.0, y=739.0, r=27.00 pixels) to coord (RA=83.633°, Dec=22.013°) with radius 0.15°
# Converting blob at (x=750.0, y=1171.0, r=27.00 pixels) to coord (RA=85.710°, Dec=23.477°) with radius 0.15°
# Plotting contours [7, 9, 12, 13, 14, 15]
# 04:08:02 WARNING   We have set the min_value of Source0.spectrum.main.Powerlaw.K to 1e-99 because  ]8;id=14999672;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=14999673;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/core/parameter.py#715\715]8;;\
#                   there was a postive transform
#          WARNING   We have set the min_value of Source1.spectrum.main.Powerlaw.K to 1e-99 because  ]8;id=14999678;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=14999679;file:///Users/rishi/Documents/Analysis/aerie/.pixi/envs/threeml/lib/python3.12/site-packages/astromodels/core/parameter.py#715\715]8;;\
#                   there was a postive transform
# 2026-07-18 04:08:02 - Pipeline - INFO - ============================================================
# 2026-07-18 04:08:02 - Pipeline - INFO - COMPLETED DRIPS SEEDING
# 2026-07-18 04:08:02 - Pipeline - INFO - Sources detected: 2
# 2026-07-18 04:08:02 - Pipeline - INFO - Iterations: 1
# 2026-07-18 04:08:02 - Pipeline - INFO - Baseline log-likelihood: nan
# 2026-07-18 04:08:02 - Pipeline - INFO - ============================================================
# Model saved to: /Users/rishi/Documents/Analysis/Sources/AstroImageDetection-fitmodel/HAWC-ImageProcessing-3MLFit//SourceDetection/curModel.model
#     Name         ra        dec   ext  Circle Radius  Sigma Radius
# 0  Drip0  83.633295  22.012621  0.15           0.15      0.098997
# 1  Drip1  85.710360  23.476832  0.15           0.15      0.098997

# %%
# # Convert HDF5 to FITS
# files = HDF5Handler.convert_hd5_to_fits(
#     input_dir='./results',
#     hd5_filename='modeltest.hd5',
#     output_basename='model',
#     logger=logger  # optional
# )
# print(f"Created {len(files)} FITS files")
